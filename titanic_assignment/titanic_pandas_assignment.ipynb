# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
new_df=pd.DataFrame({
    'dtypes':df.dtypes,
    'missing':df.isnull().sum(),
    'unique': df.nunique()
})
new_df
new_df.sort_values(by='missing',ascending=False)
# Out:
#               dtypes  missing  unique
# Cabin         object      687     147
# Age          float64      177      88
# Embarked      object        2       3
# PassengerId    int64        0     891
# Survived       int64        0       2
# Pclass         int64        0       3
# Name          object        0     891
# Sex           object        0       2
# SibSp          int64        0       7
# Parch          int64        0       7
# Ticket        object        0     681
# Fare         float64        0     248

# %%
def value_count_with_pct(value):
    count=value.value_counts()
    percent=value.value_counts(normalize=True)*100
    return pd.DataFrame({'count':count,'percentage':percent})

# %%
passanger_class=value_count_with_pct(df['Pclass'])
passanger_class
# Out:
#         count  percentage
# Pclass
# 3         491   55.106622
# 1         216   24.242424
# 2         184   20.650954

# %%
gender = value_count_with_pct(df['Sex'])
gender
# Out:
#         count  percentage
# Sex
# male      577   64.758698
# female    314   35.241302

# %%
embark = value_count_with_pct(df['Embarked'])
embark
# Out:
#           count  percentage
# Embarked
# S           644   72.440945
# C           168   18.897638
# Q            77    8.661417

# %%
female_firstclass_over_30=df[(df['Pclass']==1) & (df['Sex']=='female') & (df['Age']>=30)]
female_firstclass_over_30.sort_values(by='Fare',ascending=False).head(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 299          300         1       1
# 380          381         1       1
# 716          717         1       1
# 779          780         1       1
# 856          857         1       1
# 318          319         1       1
# 268          269         1       1
# 609          610         1       1
# 195          196         1       1
# 269          270         1       1
# 325          326         1       1
# 319          320         1       1
# 337          338         1       1
# 763          764         1       1
# 215          216         1       1
# 581          582         1       1
# 537          538         1       1
# 820          821         1       1
# 520          521         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 258                                   Ward, Miss. Anna  female  35.0      0
# ...

# %%
age_mean = df['Age'].mean()
print(age_mean)
age_median = df['Age'].median()
print(age_median)
age_mode = df['Age'].mode()
print(age_mode)
# Out:
# 29.69911764705882
# 28.0
# 0    24.0
# Name: Age, dtype: float64

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
df['Age_imputed'] = df['Age']
df['Age_imputed'] = df.groupby(['Pclass','Sex'])['Age_imputed'].transform(lambda x: x.fillna(x.median()))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Title'] = df['Name'].str.extract('([A-Za-z]+)\.', expand=False)

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: count, dtype: int64

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df['IsAlone'] = df['FamilySize']==1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.groupby('IsAlone')['Survived'].mean()*100)
# Out:
# IsAlone
# False    50.564972
# True     30.353818
# Name: Survived, dtype: float64

# %%
pivot = df.pivot_table(index='Pclass', columns='Sex', values='Survived', aggfunc='mean')
# print(pivot)
pivot
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
grouped = df.groupby(['Pclass', 'Embarked'])[['Fare', 'Age_imputed']].mean()
grouped
# Out:
#                        Fare  Age_imputed
# Pclass Embarked
# 1      C         104.718529    37.988235
#        Q          90.000000    38.500000
#        S          70.364862    38.271024
# 2      C          25.358335    23.617647
#        Q          12.350000    38.333333
#        S          20.327439    30.355671
# 3      C          11.214083    21.983636
#        Q          11.183393    24.194444
#        S          14.644083    25.453258
